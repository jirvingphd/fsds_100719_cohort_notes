# %% [markdown]
# # Capstone Office Hours + Webscraping 102 (using Selenium)

# %% [markdown]
# - 03/04/20

# %% [markdown]
# ## Capstone Questions/Comments?

# %% [markdown]
# # Using `selenium` to scrape otherwise inaccessible data

# %% [markdown]
# - [Selenium Documentation](https://www.selenium.dev/selenium/docs/api/py/api.html)
# - Installation:
#     - Selenium:
#         - https://selenium-python.readthedocs.io/installation.html
#
#     - Web Browser Drivers:
#         - https://selenium-python.readthedocs.io/installation.html#drivers

# %%
# !pip install html5lib
# !pip install -U selenium

# %%
## Webscraping imports
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import time

# %%
## additional imports
from fsds_100719.imports import *
# Out:
# fsds_1007219  v0.7.16 loaded.  Read the docs: https://fsds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_ae95ade8_5e3f_11ea_b542_acde48001122" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row1_col1" class="data row1 col1" >fsds_100719</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_ae95ade8_5e3f_11ea_b542_acde48001122row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %% [markdown]
# ## Our Task

# %% [markdown]
# - Extract all up-to-date tweets from President Trump from the [Trump Twitter Archive](http://www.trumptwitterarchive.com/)
# - Extract minute-resolution S&P 500 stock data

# %%
trump_tweets_url= 'http://www.trumptwitterarchive.com/archive'
stock_url = 'http://www.kibot.com/free_historical_data.aspx'

# %%
## Initialize the webdriver and open web-browser

driver= webdriver.Chrome()

# %%
driver.get(trump_tweets_url)

# %% [markdown]
# ## Finding Elements Using Selenium

# %% [markdown]
# - `find_element(self, by='id', value=None)`<br>Find an element given a By strategy and locator.
# Prefer the find_element_by_* methods when possible.
# - `find_element_by_class_name(self, name)`
# - `find_element_by_css_selector(self, css_selector)`
# - `find_element_by_id`
# - `find_element_by_link_text`
# - `find_element_by_name`
# - `find_element_by_partial_link_text`
# - `find_element_by_tag_name`
# - **`find_element_by_xpath`**

# %%
options = driver.find_element_by_xpath('//*[@id="options-button"]/button')
options.click()

# %%
list_of_elements = ['//*[@id="options-button"]/ul/li[4]/input',
                   '//*[@id="options-button"]/ul/li[5]/input']
for element in list_of_elements:
    driver.find_element_by_xpath(element).click()

# %%
export_element = '//*[@id="exports-button"]/button'
export = driver.find_element_by_xpath(export_element)
export.click()

# %%
# csv
driver.find_element_by_xpath('//*[@id="exports-button"]/ul/li[3]').click()

# %%
## Getting page source from driver
soup = BeautifulSoup(driver.page_source)
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <style type="text/css">
#    @charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\:form{display:block;}.ng-animate-shim{visibility:hidden;}.ng-anchor{position:absolute;}
#   </style>
#   <meta charset="utf-8"/>
#   <title>
#    Trump Twitter Archive
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="All 30,000+ of Trump's tweets, instantly searchable" name="description"/>
#   <meta content="donald trump, twitter, tweets, archive, all tweets, realDonaldTrump, politics, hillary clinton, barack obama, president, presidential race, GOP, republican, democrat" name="Keywords"/>
#   <meta content="//www.trumptwitterarchive.com" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Trump Twitter Archive" property="og:title"/>
#   <meta content="All 30,000+ of Trump's tweets, instantly searchable" property="og:description"/>
#   <meta content="//trumptwitterarchive.com/archive_screenshot.png" property="og:image"/>
#   <base href="/"/>
#   <link href="https://fonts.googleapis.com/css?family=Mukta+Vaani:400,700" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link href="style.css" rel="stylesheet" type="text/css"/>
#   <link href="/favicon.png" rel="icon" sizes="96x96" type="image/png"/>
#   <script>
#    if (window.location && window.location.hash) {
# 				window.location = window.location.href.replace('#/', '');
# 			}
#   </script>
#   <script src="http://ajax.googleapis.com/ajax/libs/angularjs/1.4.8/angular.min.js">
#   </script>
#   <script src="http://ajax.googleapis.com/ajax/libs/angularjs/1.4.8/angular-route.js">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script async="" charset="utf-8" src="http://platform.twitter.com/widgets.js">
#   </script>
#   <script src="app.js">
#   </script>
#  </head>
#  <body class="ng-scope" ng-app="myApp">
#   <nav class="navbar navbar-fixed-top navbar-inverse">
#    <div class="container-fluid">
#     <div class="navbar-header">
#      <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar-collapse-1" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="/">
#       <span>
#        Trump
#       </span>
#       Twitter Archive
#      </a>
#      <a class="navbar-text" href="/archive">
#       search through all of Trump's tweets
#      </a>
#      <p>
#      </p>
#     </div>
#     <div class="collapse navbar-collapse" id="navbar-collapse-1">
#      <ul class="nav navbar-nav navbar-right">
#       <li class="dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#         Collections
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/archive" ng-href="/archive">
#           Full Archive
#          </a>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li>
#          <a href="/highlights/authoritarianism" ng-href="/highlights/authoritarianism">
#           Authoritarianism
#          </a>
#         </li>
#         <li>
#          <a href="/highlights/birtherism" ng-href="/highlights/birtherism">
#           Birtherism
#          </a>
#         </li>
#         <li>
#          <a href="/archive/global%20warming/ftff" ng-href="/archive/global%20warming/ftff">
#           Global Warming
#          </a>
#         </li>
#         <li>
#          <a href="/highlights/profanity" ng-href="/highlights/profanity">
#           Profanity
#          </a>
#         </li>
#         <li>
#          <a href="/highlights/retaliation" ng-href="/highlights/retaliation">
#           Retaliation
#          </a>
#         </li>
#         <li>
#          <a href="/highlights/vaccines" ng-href="/highlights/vaccines">
#           Vaccines
#          </a>
#         </li>
#         <li>
#          <a href="/highlights/women" ng-href="/highlights/women">
#           Women
#          </a>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li>
#          <a href="/archive/@Lord_Sugar/ftff" ng-href="/archive/@Lord_Sugar/ftff">
#           Feud: Lord Sugar
#          </a>
#         </li>
#         <li>
#          <a href="/archive/@rosie/ftff" ng-href="/archive/@rosie/ftff">
#           Feud: Rosie O'Donnell
#          </a>
#         </li>
#         <li>
#          <a href="/archive/@macmiller/ftff" ng-href="/archive/@macmiller/ftff">
#           Feud: Mac Miller
#          </a>
#         </li>
#         <li>
#          <a href="/archive/@toure/ftff" ng-href="/archive/@toure/ftff">
#           Feud: Toure
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#         Additional Accounts
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/allaccounts" ng-href="/allaccounts">
#           See full list (50+)
#          </a>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li>
#          <a href="/archive/account/potus" ng-href="/archive/account/potus">
#           Donald Trump @potus
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/donaldjtrumpjr" ng-href="/archive/account/donaldjtrumpjr">
#           Donald Trump Jr. @donaldjtrumpjr
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/erictrump" ng-href="/archive/account/erictrump">
#           Eric Trump @erictrump
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/hillaryclinton" ng-href="/archive/account/hillaryclinton">
#           Hillary Clinton @hillaryclinton
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/ivankatrump" ng-href="/archive/account/ivankatrump">
#           Ivanka Trump @ivankatrump
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/genflynn" ng-href="/archive/account/genflynn">
#           Mike Flynn @genflynn
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/govpencein" ng-href="/archive/account/govpencein">
#           Mike Pence @govpencein
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/vp" ng-href="/archive/account/vp">
#           Mike Pence @vp
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/senatemajldr" ng-href="/archive/account/senatemajldr">
#           Mitch McConnell @senatemajldr
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/speakerryan" ng-href="/archive/account/speakerryan">
#           Paul Ryan @speakerryan
#          </a>
#         </li>
#         <li>
#          <a href="/archive/account/rogerjstonejr" ng-href="/archive/account/rogerjstonejr">
#           Roger Stone @rogerjstonejr
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#         FAQs
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/about">
#           About / FAQs
#          </a>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li>
#          <a href="mailto:trumptwitterarchive@gmail.com">
#           trumptwitterarchive@gmail.com
#          </a>
#         </li>
#         <li>
#          <a href="https://twitter.com/realtrumptweet" target="_blank">
#           @realtrumptweet
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#      <form action="https://www.paypal.com/cgi-bin/webscr" class="navbar-form navbar-right ng-pristine ng-valid" method="post" target="_blank">
#       <input name="cmd" type="hidden" value="_s-xclick"/>
#       <input name="encrypted" type="hidden" value="-----BEGIN PKCS7-----...-----END PKCS7-----"/>
#       <input class="btn btn-sm btn-primary form-control" type="submit" value="Support"/>
#       <img alt="" border="0" height="1" src="https://www.paypalobjects.com/en_US/i/scr/pixel.gif" width="1"/>
#      </form>
#     </div>
#     <!-- /.navbar-collapse -->
#    </div>
#    <!-- /.container-fluid -->
#   </nav>
#   <!-- ngView:  -->
#   <div class="view-frame ng-scope" ng-view="">
#    <div class="container-fluid ng-scope" id="archive" ng-controller="archiveCtrl">
#     <div class="center" id="export-box" ng-show="showExport">
#      <div id="export-options">
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.id_str" type="checkbox"/>
#        <label>
#         Tweet Id
#        </label>
#       </div>
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.text" type="checkbox"/>
#        <label>
#         Text
#        </label>
#       </div>
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.created_at" type="checkbox"/>
#        <label>
#         Created At (GMT)
#        </label>
#       </div>
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.favorite_count" type="checkbox"/>
#        <label>
#         Favorites
#        </label>
#       </div>
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.retweet_count" type="checkbox"/>
#        <label>
#         Retweets
#        </label>
#       </div>
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.is_retweet" type="checkbox"/>
#        <label>
#         Is Retweet
#        </label>
#       </div>
#       <div>
#        <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="exportSettings.source" type="checkbox"/>
#        <label>
#         Source
#        </label>
#       </div>
#      </div>
#      <div>
#       <input class="ng-pristine ng-untouched ng-valid ng-valid-maxlength" maxlength="1" ng-model="exportSeparator" type="text"/>
#       <button class="btn" ng-click="export('CSV')">
#        Update as CSV
#       </button>
#       <button class="btn" ng-click="export('JSON')">
#        Update as JSON
#       </button>
#       <button class="btn" ng-click="showExport = false">
#        Close
#       </button>
#      </div>
#      <textarea class="ng-pristine ng-untouched ng-valid" ng-model="exported"></textarea>
#     </div>
#     <div class="col-md-12 input-group input-group-lg" id="search-bar">
#      <span class="input-group-addon pointer ng-binding" id="sizing-addon1" ng-click="showUrlToPage()" title="click for link to this search">
#       46181
#      </span>
#      <input aria-describedby="sizing-addon1" class="form-control ng-pristine ng-untouched ng-valid" ng-model="query" placeholder="Search..." tabindex="1" type="text"/>
#      <div class="input-group-btn">
#       <button aria-expanded="false" aria-haspopup="true" class="btn btn-default dropdown-toggle" data-toggle="dropdown" type="button">
#        Tips
#        <span class="caret">
#        </span>
#       </button>
#       <ul class="dropdown-menu dropdown-menu-right">
#        <li>
#         <a href="#" ng-click="query = 'obama &amp;&amp; golf'">
#          <span>
#           obama &amp;&amp; golf
#          </span>
#          all tweets with both obama
#          <b>
#           and
#          </b>
#          golf
#         </a>
#        </li>
#        <li>
#         <a href="#" ng-click="query = 'bad || sad'">
#          <span>
#           bad || sad
#          </span>
#          all tweets with either bad
#          <b>
#           or
#          </b>
#          sad
#         </a>
#        </li>
#        <li>
#         <a href="#" ng-click="query = 'loser ~~ closer'">
#          <span>
#           loser ~~ closer
#          </span>
#          all tweets with loser but
#          <b>
#           not
#          </b>
#          closer
#         </a>
#        </li>
#        <li class="divider" role="separator">
#        </li>
#        <li>
#         <a href="#">
#          try combining operators
#         </a>
#        </li>
#        <li class="divider" role="separator">
#        </li>
#        <li>
#         <a href="#">
#          click the number on the left for a link to your search
#         </a>
#        </li>
#       </ul>
#      </div>
#      <span class="input-group-addon ng-binding" id="sizing-addon2">
#       @realdonaldtrump
#      </span>
#     </div>
#     <div class="col-md-12" id="control-bar">
#      <div id="control-buttons">
#       <div class="dropdown" id="exports-button">
#        <button aria-expanded="false" class="btn btn-danger form-control" data-toggle="dropdown" type="button">
#         Export
#         <span class="caret">
#         </span>
#        </button>
#        <ul class="dropdown-menu">
#         <li>
#          <b>
#           Performance slow over 10,000 items
#          </b>
#         </li>
#         <li class="divider" role="separator">
#         </li>
#         <li class="pointer" ng-click="export('CSV')">
#          CSV (for MS Excel)
#         </li>
#         <li class="pointer" ng-click="export('JSON')">
#          JSON
#         </li>
#        </ul>
#       </div>
#       <div class="dropdown" id="options-button">
#        <button aria-expanded="false" class="btn btn-danger form-control" data-toggle="dropdown" type="button">
#         Options
#         <span class="caret">
#         </span>
#        </button>
#        <ul class="dropdown-menu">
#         <li>
#          <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="settings.exactMatch" type="checkbox"/>
#          exact word search
#         </li>
#         <li>
#          <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="settings.retweets" type="checkbox"/>
#          show retweets
#         </li>
#         <li>
#          <input class="pointer ng-pristine ng-untouched ng-valid" ng-model="settings.showManualRetweets" type="checkbox"/>
#          show manual retweets
#         </li>
#         <!-- ngIf: hasRetweetsAndFavorites -->
#         <li class="ng-scope" ng-if="hasRetweetsAndFavorites">
#          <input class="pointer ng-valid ng-dirty ng-valid-parse ng-touched" ng-model="settings.showRetweetCount" type="checkbox"/>
#          show retweet count
#         </li>
#         <!-- end ngIf: hasRetweetsAndFavorites -->
#         <!-- ngIf: hasRetweetsAndFavorites -->
#         <li class="ng-scope" ng-if="hasRetweetsAndFavorites">
#          <input class="pointer ng-valid ng-dirty ng-valid-parse ng-touched" ng-model="settings.showFavoriteCount" type="checkbox"/>
#          show favorite count
#         </li>
#         <!-- end ngIf: hasRetweetsAndFavorites -->
#         <!-- ngIf: hasRetweetsAndFavorites -->
#         <li class="ng-scope" ng-if="hasRetweetsAndFavorites">
#          <input class="pointer" ng-checked="orderBy === 'retweet_count'" ng-click="setOrder('retweet_count')" type="checkbox"/>
#          order by retweet count
#         </li>
#         <!-- end ngIf: hasRetweetsAndFavorites -->
#         <!-- ngIf: hasRetweetsAndFavorites -->
#         <li class="ng-scope" ng-if="hasRetweetsAndFavorites">
#          <input class="pointer" ng-checked="orderBy === 'favorite_count'" ng-click="setOrder('favorite_count')" type="checkbox"/>
#          order by favorite count
#         </li>
#         <!-- end ngIf: hasRetweetsAndFavorites -->
#        </ul>
#       </div>
#       <button class="btn btn-danger" ng-click="settings.descending = !settings.descending">
#        <!-- ngIf: settings.descending -->
#        <span class="ng-scope" ng-if="settings.descending">
#         ↓
#        </span>
#        <!-- end ngIf: settings.descending -->
#        <!-- ngIf: !settings.descending -->
#       </button>
#      </div>
#      <div id="control-dates">
#       <input class="ng-pristine ng-untouched ng-valid" ng-model="dateRange.start" placeholder="yyyy-MM-dd" type="date"/>
#       <input class="ng-pristine ng-untouched ng-valid" ng-model="dateRange.end" placeholder="yyyy-MM-dd" type="date"/>
#      </div>
#      <div id="control-selects">
#       <select class="ng-pristine ng-untouched ng-valid" ng-model="times.time">
#        <!-- ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="Any time">
#         Any time
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="12:00am">
#         12:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="1:00am">
#         1:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="2:00am">
#         2:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="3:00am">
#         3:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="4:00am">
#         4:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="5:00am">
#         5:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="6:00am">
#         6:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="7:00am">
#         7:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="8:00am">
#         8:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="9:00am">
#         9:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="10:00am">
#         10:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="11:00am">
#         11:00am
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="12:00pm">
#         12:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="1:00pm">
#         1:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="2:00pm">
#         2:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="3:00pm">
#         3:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="4:00pm">
#         4:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="5:00pm">
#         5:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="6:00pm">
#         6:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="7:00pm">
#         7:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="8:00pm">
#         8:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="9:00pm">
#         9:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="10:00pm">
#         10:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#        <option class="ng-binding ng-scope" ng-repeat="hour in times.options" value="11:00pm">
#         11:00pm
#        </option>
#        <!-- end ngRepeat: hour in times.options -->
#       </select>
#       <select class="ng-pristine ng-untouched ng-valid" ng-model="sources.source">
#        <!-- ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="All devices">
#         All devices
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Facebook">
#         Facebook
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Instagram">
#         Instagram
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Media Studio">
#         Media Studio
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Mobile Web (M5)">
#         Mobile Web (M5)
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Neatly For BlackBerry 10">
#         Neatly For BlackBerry 10
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Periscope">
#         Periscope
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="TweetDeck">
#         TweetDeck
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="TwitLonger Beta">
#         TwitLonger Beta
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitlonger">
#         Twitlonger
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter Ads">
#         Twitter Ads
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter Media Studio">
#         Twitter Media Studio
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter Mirror for iPad">
#         Twitter Mirror for iPad
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter QandA">
#         Twitter QandA
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter Web App">
#         Twitter Web App
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter Web Client">
#         Twitter Web Client
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter for Android">
#         Twitter for Android
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter for BlackBerry">
#         Twitter for BlackBerry
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter for Websites">
#         Twitter for Websites
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter for iPad">
#         Twitter for iPad
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Twitter for iPhone">
#         Twitter for iPhone
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#        <option class="ng-binding ng-scope" ng-repeat="source in sources.options" value="Vine - Make a Scene">
#         Vine - Make a Scene
#        </option>
#        <!-- end ngRepeat: source in sources.options -->
#       </select>
#      </div>
#     </div>
#     <div class="col-md-12" id="results">
#      <ol id="fixed" when-scrolled="loadMore()">
#       <!-- ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 11:06:04 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          Mini Mike, “Three months ago I entered the race for President to defeat Donald Trump, (and I failed miserably!).
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 8553]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 43615]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235235070040059904" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 10:57:08 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          Mini Mike Bloomberg will now FIRE Tim O’Brien, and all of the fools and truly dumb people who got him into this MESS. This has been the worst, and most embarrassing, experience of his life...and now on to Sleepy Joe!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 7710]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 35074]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235232818692792320" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 10:40:01 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          Mini Mike Bloomberg just “quit” the race for President. I could have told him long ago that he didn’t have what it takes, and he would have saved himself a billion dollars, the real cost. Now he will pour money into Sleepy Joe’s campaign, hoping to save face. It won’t work!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 14740]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 69452]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235228511314620416" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 10:32:30 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          The Mayor of Los Angeles, @ericgarcetti, is dealing with us trying to get the Federal Government to fix the terrible problem he and the Dems have caused with the homeless, and the horrendous effects it is having on the City, which is a mess. I then watch him talk “trash” on me!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 7940]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 28429]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235226619528335369" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 10:21:44 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          Wow! If Elizabeth Warren wasn’t in the race, Bernie Sanders would have EASILY won Massachusetts, Minnesota and Texas, not to mention various other states. Our modern day Pocahontas won’t go down in history as a winner, but she may very well go down as the all time great SPOILER!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 13422]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 64784]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235223911538872323" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 09:56:01 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          The great people of Montana can have no better VOICE than Senator @SteveDaines. He is doing an incredible job! Whoever the Democrat nominee may be, please understand that I will be working hard with Steve all the way, &amp; last night I was 20 for 20 (per @GOPLeader). WE NEED STEVE!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 6007]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 23685]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235217440285560835" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 09:20:44 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          I will be going to the Great State of Tennessee on Friday. The USA stands with the people of Tennessee 100%, whatever they need! The tornadoes were of record size &amp; velocity. God bless your loved ones &amp; all of the families affected! Thanks to @GovBillLee &amp; @MarshaBlackburn
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 9017]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 38310]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235208558666543104" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 07:48:23 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          MAKE AMERICA GREAT AGAIN and then, KEEP AMERICA GREAT!!!!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 25240]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 132807]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235185319257006080" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 07:31:24 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          This is what happens to someone who loyally gets appointed Attorney General of the United States &amp; then doesn’t have the wisdom or courage to stare down &amp; end the phony Russia Witch Hunt. Recuses himself on FIRST DAY in office, and the Mueller Scam begins! https://t.co/2jGnRgOS6h
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 11583]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 42426]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235181043881299969" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 07:18:04 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          RT @AP_Politics: BREAKING: Republican Tommy Tuberville advances to primary runoff for U.S. Senate in Alabama primary election. #APracecall…
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 3510]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 0]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235177691680301058" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 07:12:29 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          So selfish for Elizabeth Warren to stay in the race. She has Zero chance of even coming close to winning, but hurts Bernie badly. So much for their wonderful liberal friendship. Will he ever speak to her again? She cost him Massachusetts (and came in third), he shouldn’t!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 14708]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 77700]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235176283740524546" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 06:52:25 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          The Democrat establishment came together and crushed Bernie Sanders, AGAIN! Even the fact that Elizabeth Warren stayed in the race was devastating to Bernie and allowed Sleepy Joe to unthinkably win Massachusetts. It was a perfect storm, with many good states remaining for Joe!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 12589]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 53378]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235171235505598465" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 01:25:09 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          RT @realDonaldTrump: Mini Mike, don’t lick your dirty fingers. Both unsanitary and dangerous to others and yourself! https://t.co/LsKLZNeZL9
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 37749]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 0]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235088876256944129" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 12:59:06 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          THANK YOU CALIFORNIA! #KAG2020 https://t.co/7BrkAKYWU0
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 10104]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 47351]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235082320161325057" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 12:58:38 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          THANK YOU UTAH! #KAG2020 https://t.co/LrCvXgmp3X
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 7106]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 32217]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235082200690745344" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 12:41:45 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          RT @brithume: Good insight here. But there is one unifying factor that will be there in the fall: Donald J. Trump.
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 4409]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 0]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1235077953635020801" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 4, 2020 12:41:00 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
# ...
#          [RT 15775]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 62450]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1234497829298679809" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 2, 2020 09:19:23 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          Jack Welch, former Chairman and CEO of GE, a business legend, has died. There was no corporate leader like “neutron” Jack. He was my friend and supporter. We made wonderful deals together. He will never be forgotten. My warmest sympathies to his wonderful wife &amp; family!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 15771]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 81398]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1234483443712561157" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 2, 2020 07:55:20 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          I was criticized by the Democrats when I closed the Country down to China many weeks ahead of what almost everyone recommended. Saved many lives. Dems were working the Impeachment Hoax. They didn’t have a clue! Now they are fear mongering. Be calm &amp; vigilant!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 36442]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 159421]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1234462291652993032" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 2, 2020 07:42:49 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          “Ever since (Mini Mike) Bloomberg’s bad debate performances, his support has dropped.” @abcnews  Dropped a lot. Only his highly paid consultants, who are laughing all the way to the bank, still support him...And by the way, he did not poll well as mayor in handling crisis!
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 11418]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 49583]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1234459143790112770" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#       <li class="ng-scope" ng-repeat="tweet in displayed">
#        <span class="tweet-date ng-binding" ng-bind-html="tweet | dateformat">
#         Mar 2, 2020 07:31:41 AM
#        </span>
#        <span class="tweet-data">
#         <span class="tweet-text ng-binding" ng-bind-html="tweet | highlight:query:deepQuery:settings.exactMatch">
#          RT @TwitterMoments: President Trump and VP Mike Pence provided further updates on the coronavirus outbreak, including travel advisories for…
#         </span>
#         <span class="tweet-source ng-binding">
#          [Twitter for iPhone]
#         </span>
#         <!-- ngIf: settings.showRetweetCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showRetweetCount">
#          [RT 4589]
#         </span>
#         <!-- end ngIf: settings.showRetweetCount -->
#         <!-- ngIf: settings.showFavoriteCount -->
#         <span class="tweet-source ng-binding ng-scope" ng-if="settings.showFavoriteCount">
#          [❤ 0]
#         </span>
#         <!-- end ngIf: settings.showFavoriteCount -->
#         <a href="https://twitter.com/realdonaldtrump/status/1234456341948903425" target="_blank">
#          <button class="btn btn-xs">
#           link
#          </button>
#         </a>
#        </span>
#       </li>
#       <!-- end ngRepeat: tweet in displayed -->
#      </ol>
#     </div>
#     <div class="ng-hide" id="loading-icon" ng-hide="loaded.length">
#      <svg class="uil-default" height="120px" preserveaspectratio="xMidYMid" viewbox="0 0 100 100" width="120px" xmlns="http://www.w3.org/2000/svg">
#       <rect class="bk" fill="none" height="100" width="100" x="0" y="0">
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(0 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(30 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.08333333333333333s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(60 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.16666666666666666s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(90 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.25s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(120 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.3333333333333333s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(150 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.4166666666666667s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(180 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.5s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(210 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.5833333333333334s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(240 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.6666666666666666s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(270 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.75s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(300 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.8333333333333334s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#       <rect fill="#00b2ff" height="20" rx="5" ry="5" transform="rotate(330 50 50) translate(0 -30)" width="7" x="46.5" y="40">
#        <animate attributename="opacity" begin="0.9166666666666666s" dur="1s" from="1" repeatcount="indefinite" to="0">
#        </animate>
#       </rect>
#      </svg>
#     </div>
#     <div class="ng-hide" id="loaded-dates" ng-show="showModal">
#      <!-- ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2009
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2010
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2011
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2012
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2013
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2014
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2015
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2016
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2017
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2018
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2019
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <span class="date ng-binding ng-scope" ng-repeat="date in loaded | orderBy : 'year' ">
#       2020
#       <!-- ngIf: date.status == 'loading' -->
#       <!-- ngIf: date.status == 'success' -->
#       <span class="mark-success ng-scope" ng-if="date.status == 'success'">
#        ✓
#       </span>
#       <!-- end ngIf: date.status == 'success' -->
#       <!-- ngIf: date.status == 'failure' -->
#      </span>
#      <!-- end ngRepeat: date in loaded | orderBy : 'year' -->
#      <button class="btn btn-xs btn-danger" ng-click="removeDatesModal()">
#       close
#      </button>
#     </div>
#    </div>
#   </div>
#   <iframe allowtransparency="true" frameborder="0" scrolling="no" src="https://platform.twitter.com/widgets/widget_iframe.7aeb03ce9f308997020e5998720fbbf7.html?origin=http%3A%2F%2Fwww.trumptwitterarchive.com" style="display: none;" title="Twitter settings iframe">
#   </iframe>
#  </body>
# </html>

# %%
txt_area=soup.find_all('textarea')

# %%
txt_area[0].text
# Out:
# ''

# %%
txt_xpath = '//*[@id="export-box"]/textarea'
txt_area = driver.find_element_by_xpath(txt_xpath)

# %%
actions = ActionChains(driver)
actions.click(txt_area).perform()
actions.key_down(Keys.COMMAND).send_keys('a').key_up(Keys.COMMAND).perform()

# %% [markdown]
# # Stock Data

# %%
'http://api.kibot.com/?action=history&symbol=IVE&interval=tickbidask1&bp=1&user=guest'
