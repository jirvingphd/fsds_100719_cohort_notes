# %% [markdown]
# # Sect 35: Ensemble Methods

# %% [markdown]
# # Learning Objectives

# %% [markdown]
# - Learn about various ensemble methods:
#     - Bootstrap Aggregation (Bagging)
#     - RandomForests
#     - Model stacking

# %% [markdown]
# # Random Forests

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-random-forests-online-ds-ft-100719/master/images/new_rf-diagram.png">
